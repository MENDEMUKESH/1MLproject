# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
import pandas as pd

# %%
df = pd.read_csv('Book1.csv')

df
# Out:
#     age  weight
# 0    12      23
# 1    13      25
# 2    14      30
# 3    15      35
# 4    16      60
# 5    17      65
# 6    18      71
# 7    19      72
# 8    20      78
# 9    40      80
# 10   50      80
# 11   60      69

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   age     12 non-null     int64
#  1   weight  12 non-null     int64
# dtypes: int64(2)
# memory usage: 320.0 bytes

# %%
df.mean()
# Out:
# age       24.500000
# weight    57.333333
# dtype: float64

# %%
df.median()
# Out:
# age       17.5
# weight    67.0
# dtype: float64

# %%
df.mode()
# Out:
#     age  weight
# 0    12    80.0
# 1    13     NaN
# 2    14     NaN
# 3    15     NaN
# 4    16     NaN
# 5    17     NaN
# 6    18     NaN
# 7    19     NaN
# 8    20     NaN
# 9    40     NaN
# 10   50     NaN
# 11   60     NaN

# %%
df.std()
# Out:
# age       16.127334
# weight    22.418877
# dtype: float64

# %%
df.var()
# Out:
# age       260.090909
# weight    502.606061
# dtype: float64

# %%
df.cov()
# Out:
#                age      weight
# age     260.090909  209.181818
# weight  209.181818  502.606061

# %%
plt.scatter(age ,weight);
plt.xlabel('age');
plt.ylabel('weight')
plt.show()

# %%
plt.plot(df["age"],df["weight"]);
plt.xlabel('Age');
plt.ylabel('Weight');
plt.show()
